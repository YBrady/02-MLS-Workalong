# %% [markdown]
# # Playing with Neurons #
# Workalong with Machine Learning & Statistics Module week 9.

# %%
# Import the packages
import matplotlib.pyplot as plt
import numpy as np
import keras as kr
# Out:
# Using TensorFlow backend.

# %%
# Setting a plot size
plt.rcParams['figure.figsize'] = (10, 10)

# %%
# Array of evenly spaced numbers
x = np.linspace(-10.0, 10.0, 2000)

# Creating 3 arrays
y_l = (3.0 * x) + 5.0 # y_l - linear 
y_p = (x * x) - 41.0 # y_p - polynomial
y_s = 10.0 * np.sin(2.0 * x) # y_s - sinoidal

# %%
# PLot the 3 arrays
# See using Latex in labels!
plt.plot(x, y_l, label='$3x + 5$')
plt.plot(x, y_p, label='$x^2 - 41$')
plt.plot(x, y_s, label='$10 \sin(2x)$')

plt.legend()

# %%
y = y_l 
#y = y_p
#y = y_s

# Create a new neural network.
m = kr.models.Sequential()

# Add neurons.
#m.add(kr.layers.Dense(1, input_dim=1, activation="linear"))

# Add neurons
# TO optimise you can change the 10 value and / or the activation
m.add(kr.layers.Dense(10, input_dim=1, activation="tanh")) 
# tanh always give values from 0 and 1 for positive y and 0 and -1 for negative 9
m.add(kr.layers.Dense(10, activation="linear"))
m.add(kr.layers.Dense(1, activation='linear'))

# Compile the model.
# To optimise you could change loss from mean squared error but best no to.
# Could change optimiser too
m.compile(loss="mean_squared_error", optimizer="adam")

# Train the model.
# To optimise you can always change the epochs and batch size
m.fit(x, y, epochs=15, batch_size=10)
# epochs = no of time to perform training
# bathc_size = no of values to use each time

# Run each x value through the neural network.
p = m.predict(x)

# Plot the values.
plt.plot(x, p, 'r-', label='Prediction')
plt.plot(x, y, 'k:', label='Original')
plt.legend()
# Out:
# Epoch 1/15
# 2000/2000 [==============================] - 1s 677us/step - loss: 49.1418
# Epoch 2/15
# 2000/2000 [==============================] - 1s 274us/step - loss: 49.0266
# Epoch 3/15
# 2000/2000 [==============================] - 1s 258us/step - loss: 48.9644
# Epoch 4/15
# 2000/2000 [==============================] - 1s 278us/step - loss: 48.8692
# Epoch 5/15
# 2000/2000 [==============================] - 1s 270us/step - loss: 48.7559
# Epoch 6/15
# 2000/2000 [==============================] - 1s 269us/step - loss: 48.5846
# Epoch 7/15
# 2000/2000 [==============================] - 1s 272us/step - loss: 48.4077
# Epoch 8/15
# 2000/2000 [==============================] - 0s 246us/step - loss: 48.2054
# Epoch 9/15
# 2000/2000 [==============================] - 1s 289us/step - loss: 47.9854
# Epoch 10/15
# 2000/2000 [==============================] - 1s 275us/step - loss: 47.8154
# Epoch 11/15
# 2000/2000 [==============================] - 1s 258us/step - loss: 47.5482
# Epoch 12/15
# 2000/2000 [==============================] - 1s 262us/step - loss: 47.2617
# Epoch 13/15
# 2000/2000 [==============================] - 0s 242us/step - loss: 47.0112
# Epoch 14/15
# 2000/2000 [==============================] - 1s 276us/step - loss: 46.8264
# Epoch 15/15
# 2000/2000 [==============================] - 0s 236us/step - loss: 46.5058

# %% [markdown]
# ## End ##
